# %%
import pandas as pd


data = pd.read_csv('/content/Quote-Equity-ASIANPAINT-EQ-29-03-2023-to-29-06-2023.csv')#Train data 3 months
data1= pd.read_csv('/content/Quote-Equity-ASIANPAINT-EQ-29-06-2023-to-29-07-2023.csv')#Test data 1 months

print(data.isnull().sum())
print(data1.isnull().sum())

data.fillna(method ='ffill', inplace = True)
data.fillna(method ='ffill', inplace = True)
# Out:
# Date             0
# series           0
# OPEN             0
# HIGH             0
# LOW              0
# PREV. CLOSE      0
# ltp              0
# close            0
# vwap             0
# 52W H            0
# 52W L            0
# VOLUME           0
# VALUE            0
# No of trades     0
# dtype: int64
# Date             0
# series           0
# OPEN             0
# HIGH             0
# LOW              0
# PREV. CLOSE      0
# ltp              0
# close            0
# vwap             0
# 52W H            0
# 52W L            0
# VOLUME           0
# VALUE            0
# No of trades     0
# dtype: int64

# %%
print(data.columns)
# Out:
# Index(['Date ', 'series ', 'OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ', 'ltp ',
#        'close ', 'vwap ', '52W H ', '52W L ', 'VOLUME ', 'VALUE ',
#        'No of trades '],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split


X = data[['OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ']]
y = data['close ']
X_1 = data1[['OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ']]
y_1 = data1['close ']

X = X.replace(',', '', regex=True).astype(float)
y = y.replace(',', '', regex=True).astype(float)
X_1 = X.replace(',', '', regex=True).astype(float)
y_1 = y.replace(',', '', regex=True).astype(float)


X_train = X
y_train = y
X_test = X_1
y_test = y_1

# %%
from sklearn.linear_model import LinearRegression

# Define the model
model = LinearRegression()


model.fit(X_train, y_train)

y_pred = model.predict(X_test)

from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()


sns.lineplot(data=y_test, label='Actual')
sns.lineplot(data=y_pred, label='Predicted')
# Out:
# Mean Squared Error: 145.12278650121837
# <Axes: ylabel='close '>
